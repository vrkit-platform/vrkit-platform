# %%
import json
import tabula

file1 = "Y:/code/sim-racing/irsdk++/docs/telemetry_11_23_15.pdf"
table = tabula.read_pdf(file1, pages="1-9")

all_vars = []
for frame in table:
    name_series = frame['Name'].tolist()
    unit_series = frame['Unit'].tolist()
    type_series = frame['Type'].tolist()
    disk_series = frame['Disk'].tolist()
    live_series = frame['Live'].tolist()
    desc_series = frame['Description'].tolist()

    table_vars = list(zip(name_series, unit_series, type_series, disk_series, live_series, desc_series))
    all_vars.extend(table_vars)

def enum_var_names():
    return '\n'.join([record[0] + "," for record in all_vars])

code = (f"""
enum IRAllVarName {{
  {enum_var_names()}   
}};        
""")
# Out:
# [
#   [
#     "AirDensity",
#     "kg/m^3",
#     "float",
#     1,
#     1,
#     "Density of air at start/finish line"
#   ],
#   [
#     "AirPressure",
#     "Hg",
#     "float",
#     1,
#     1,
#     "Pressure of air at start/finish line"
#   ],
#   [
#     "AirTemp",
#     "C",
#     "float",
#     1,
#     1,
#     "Temperature of air at start/finish line"
#   ],
#   [
#     "Alt",
#     "m",
#     "float",
#     1,
#     1,
#     "Altitude in meters"
#   ],
#   [
#     "Brake",
#     "%",
#     "float",
#     1,
#     1,
#     "0=brake released to 1=max pedal force"
#   ],
#   [
#     "BrakeRaw",
#     "%",
#     "float",
#     1,
#     1,
#     "Raw brake input 0=brake released to 1=max pedal force"
#   ],
#   [
#     "CamCameraNumber",
#     NaN,
#     "int",
#     0,
#     1,
#     "Active camera number"
#   ],
#   [
#     "CamCameraState",
#     "irsdk_CameraState",
#     "bitfield",
#     0,
#     1,
#     "State of camera system"
#   ],
#   [
#     "CamCarIdx",
#     NaN,
#     "int",
#     0,
#     1,
#     "Active camera's focus car index"
#   ],
#   [
#     "CamGroupNumber",
#     NaN,
#     "int",
#     0,
#     1,
#     "Active camera group number"
#   ],
#   [
#     "Clutch",
#     "%",
#     "float",
#     1,
#     1,
#     "0=disengaged to 1=fully engaged"
#   ],
#   [
#     "CpuUsageBG",
#     "%",
#     "float",
#     1,
#     1,
#     "Percent of available tim bg thread took with a 1 sec avg"
#   ],
#   [
#     "DCDriversSoFar",
#     NaN,
#     "int",
#     0,
#     1,
#     "Number of team drivers who have run a stint"
#   ],
#   [
#     "DCLapStatus",
#     NaN,
#     "int",
#     0,
#     1,
#     "Status of driver change lap requirements"
#   ],
#   [
#     "DisplayUnits",
#     NaN,
#     "int",
#     0,
#     1,
#     "Default units for the user interface 0 = english 1 = metric"
#   ],
#   [
#     "DriverMarker",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Driver activated flag"
#   ],
#   [
#     "EngineWarnings",
#     "irsdk_EngineWarnings",
#     "bitfield",
#     1,
#     1,
#     "Bitfield for warning lights"
#   ],
#   [
#     "EnterExitReset",
#     NaN,
#     "int",
#     1,
#     1,
#     "Indicate action the reset key will take 0 enter 1 exit 2 reset"
#   ],
#   [
#     "FogLevel",
#     "%",
#     "float",
#     1,
#     1,
#     "Fog level"
#   ],
#   [
#     "FrameRate",
#     "fps",
#     "float",
#     1,
#     1,
#     "Average frames per second"
#   ],
#   [
#     "FuelLevel",
#     "l",
#     "float",
#     1,
#     1,
#     "Liters of fuel remaining"
#   ],
#   [
#     "FuelLevelPct",
#     "%",
#     "float",
#     1,
#     1,
#     "Percent fuel remaining"
#   ],
#   [
#     "FuelPress",
#     "bar",
#     "float",
#     1,
#     1,
#     "Engine fuel pressure"
#   ],
#   [
#     "FuelUsePerHour",
#     "kg/h",
#     "float",
#     1,
#     1,
#     "Engine fuel used instantaneous"
#   ],
#   [
#     "Gear",
#     NaN,
#     "int",
#     1,
#     1,
#     "-1=reverse  0=neutral  1..n=current gear"
#   ],
#   [
#     "IsDiskLoggingActive",
#     NaN,
#     "bool",
#     0,
#     1,
#     "0=disk based telemetry file not being written  1=being written"
#   ],
#   [
#     "IsDiskLoggingEnabled",
#     NaN,
#     "bool",
#     0,
#     1,
#     "0=disk based telemetry turned off  1=turned on"
#   ],
#   [
#     "IsInGarage",
#     NaN,
#     "bool",
#     0,
#     1,
#     "1=Car in garage physics running"
#   ],
#   [
#     "IsOnTrack",
#     NaN,
#     "bool",
#     1,
#     1,
#     "1=Car on track physics running with player in car"
#   ],
#   [
#     "IsOnTrackCar",
#     NaN,
#     "bool",
#     1,
#     1,
#     "1=Car on track physics running"
#   ],
#   [
#     "IsReplayPlaying",
#     NaN,
#     "bool",
#     0,
#     1,
#     "0=replay not playing  1=replay playing"
#   ],
#   [
#     "Lap",
#     NaN,
#     "int",
#     1,
#     1,
#     "Lap count"
#   ],
#   [
#     "LapBestLap",
#     NaN,
#     "int",
#     1,
#     1,
#     "Players best lap number"
#   ],
#   [
#     "LapBestLapTime",
#     "s",
#     "float",
#     1,
#     1,
#     "Players best lap time"
#   ],
#   [
#     "LapBestNLapLap",
#     NaN,
#     "int",
#     1,
#     1,
#     "Player last lap in best N average lap time"
#   ],
#   [
#     "LapBestNLapTime",
#     "s",
#     "float",
#     1,
#     1,
#     "Player best N average lap time"
#   ],
#   [
#     "LapCurrentLapTime",
#     "s",
#     "float",
#     1,
#     1,
#     "Estimate of players current lap time as shown in F3 box"
#   ],
#   [
#     "LapDeltaToBestLap",
#     "s",
#     "float",
#     1,
#     1,
#     "Delta time for best lap"
#   ],
#   [
#     "LapDeltaToBestLap_DD",
#     "s/s",
#     "float",
#     1,
#     1,
#     "Rate of change of delta time for best lap"
#   ],
#   [
#     "LapDeltaToBestLap_OK",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Delta time for best lap is valid"
#   ],
#   [
#     "LapDeltaToOptimalLap",
#     "s",
#     "float",
#     1,
#     1,
#     "Delta time for optimal lap"
#   ],
#   [
#     "LapDeltaToOptimalLap_DD",
#     "s/s",
#     "float",
#     1,
#     1,
#     "Rate of change of delta time for optimal lap"
#   ],
#   [
#     "LapDeltaToOptimalLap_OK",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Delta time for optimal lap is valid"
#   ],
#   [
#     "LapDeltaToSessionBestLap",
#     "s",
#     "float",
#     1,
#     1,
#     "Delta time for session best lap"
#   ],
#   [
#     "LapDeltaToSessionBestLap_DD",
#     "s/s",
#     "float",
#     1,
#     1,
#     "Rate of change of delta time for session best lap"
#   ],
#   [
#     "LapDeltaToSessionBestLap_OK",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Delta time for session best lap is valid"
#   ],
#   [
#     "LapDeltaToSessionLastlLap",
#     "s",
#     "float",
#     1,
#     1,
#     "Delta time for session last lap"
#   ],
#   [
#     "LapDeltaToSessionLastlLap_DD",
#     "s/s",
#     "float",
#     1,
#     1,
#     "Rate of change of delta time for session last lap"
#   ],
#   [
#     "LapDeltaToSessionLastlLap_OK",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Delta time for session last lap is valid"
#   ],
#   [
#     "LapDeltaToSessionOptimalLap",
#     "s",
#     "float",
#     1,
#     1,
#     "Delta time for session optimal lap"
#   ],
#   [
#     "LapDeltaToSessionOptimalLap_DD",
#     "s/s",
#     "float",
#     1,
#     1,
#     "Rate of change of delta time for session optimal lap"
#   ],
#   [
#     "LapDeltaToSessionOptimalLap_OK",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Delta time for session optimal lap is valid"
#   ],
#   [
#     "LapDist",
#     "m",
#     "float",
#     1,
#     1,
#     "Meters traveled from S/F this lap"
#   ],
#   [
#     "LapDistPct",
#     "%",
#     "float",
#     1,
#     1,
#     "Percentage distance around lap"
#   ],
#   [
#     "LapLasNLapSeq",
#     NaN,
#     "int",
#     1,
#     1,
#     "Player num consecutive clean laps completed for N average"
#   ],
#   [
#     "LapLastLapTime",
#     "s",
#     "float",
#     1,
#     1,
#     "Players last lap time"
#   ],
#   [
#     "LapLastNLapTime",
#     "s",
#     "float",
#     1,
#     1,
#     "Player last N average lap time"
#   ],
#   [
#     "Lat",
#     "deg",
#     "double",
#     1,
#     1,
#     "Latitude in decimal degrees"
#   ],
#   [
#     "LatAccel",
#     "m/s^2",
#     "float",
#     1,
#     1,
#     "Lateral acceleration (including gravity)"
#   ],
#   [
#     "Lon",
#     "deg",
#     "double",
#     1,
#     1,
#     "Longitude in decimal degrees"
#   ],
#   [
#     "LongAccel",
#     "m/s^2",
#     "float",
#     1,
#     1,
#     "Longitudinal acceleration (including gravity)"
#   ],
#   [
#     "ManifoldPress",
#     "bar",
#     "float",
#     1,
#     1,
#     "Engine manifold pressure"
#   ],
#   [
#     "OilLevel",
#     "l",
#     "float",
#     1,
#     1,
#     "Engine oil level"
#   ],
#   [
#     "OilPress",
#     "bar",
#     "float",
#     1,
#     1,
#     "Engine oil pressure"
#   ],
#   [
#     "OilTemp",
#     "C",
#     "float",
#     1,
#     1,
#     "Engine oil temperature"
#   ],
#   [
#     "OnPitRoad",
#     NaN,
#     "bool",
#     1,
#     1,
#     "Is the player car on pit road between the cones"
#   ],
#   [
#     "Pitch",
#     "r ad",
#     "float",
#     1,
#     1,
#     "Pitch orientation"
#   ],
#   [
#     "PitchRate",
#     "rad/s",
#     "float",
#     1,
#     1,
#     "Pitch rate"
#   ],
#   [
#     "PitOptRepairLeft",
#     "s",
#     "float",
#     1,
#     1,
#     "Time left for optional repairs if repairs are active"
#   ],
#   [
#     "PitRepairLeft",
#     "s",
#     "float",
#     1,
#     1,
#     "Time left for mandatory pit repairs if repairs are active"
#   ],
#   [
#     "PitSvFlags",
#     "irsdk_PitSvFlags",
#     "bitfield",
#     1,
#     1,
#     "Bitfield of pit service checkboxes"
#   ],
#   [
#     "PitSvFuel",
#     "l",
#     "float",
#     1,
#     1,
#     "Pit service fuel add amount"
#   ],
#   [
#     "PitSvLFP",
#     "kPa",
#     "float",
#     1,
#     1,
#     "Pit service left front tire pressure"
#   ],
#   [
#     "PitSvLRP",
#     "kPa",
#     "float",
#     1,
#     1,
#     "Pit service left rear tire pressure"
#   ],
#   [
#     "PitSvRFP",
#     "kPa",
#     "float",
#     1,
#     1,
#     "Pit service right front tire pressure"
#   ],
#   [
#     "PitSvRRP",
#     "kPa",
#     "float",
#     1,
#     1,
#     "Pit service right rear tire pressure"
#   ],
#   [
#     "PlayerCarClassPosition",
#     NaN,
#     "int",
#     1,
#     1,
#     "Players class position in race"
#   ],
#   [
#     "PlayerCarPosition",
#     NaN,
#     "int",
#     1,
#     1,
#     "Players position in race"
#   ],
#   [
#     "RaceLaps",
#     NaN,
#     "int",
#     0,
#     1,
#     "Laps completed in race"
#   ],
#   [
#     "RadioTransmitCarIdx",
#     NaN,
#     "int",
#     0,
#     1,
#     "The car index of the current person speaking on the radio"
#   ],
#   [
#     "RadioTransmitFrequencyIdx",
#     NaN,
#     "int",
#     0,
#     1,
#     "The frequency index of the current person speaking on the raio"
#   ],
#   [
#     "RadioTransmitRadioIdx",
#     NaN,
#     "int",
#     0,
#     1,
#     "The radio index of the current person speaking on the radio"
#   ],
#   [
#     "RelativeHumidity",
#     "%",
#     "float",
#     1,
#     1,
#     "Relative Humidity"
#   ],
#   [
#     "ReplayFrameNum",
#     NaN,
#     "int",
#     0,
#     1,
#     "Integer replay frame number (60 per second)"
#   ],
#   [
#     "ReplayFrameNumEnd",
#     NaN,
#     "int",
#     0,
#     1,
#     "Integer replay frame number from end of tape"
#   ],
#   [
#     "ReplayPlaySlowMotion",
#     NaN,
#     "bool",
#     0,
#     1,
#     "0=not slow motion  1=replay is in slow motion"
#   ],
#   [
#     "ReplayPlaySpeed",
#     NaN,
#     "int",
#     0,
#     1,
#     "Replay playback speed"
#   ],
#   [
#     "ReplaySessionNum",
#     NaN,
#     "int",
#     0,
#     1,
#     "Replay session number"
#   ],
#   [
#     "ReplaySessionTime",
#     "s",
#     "double",
#     0,
#     1,
#     "Seconds since replay session start"
#   ],
#   [
#     "Roll",
#     "rad",
#     "float",
#     1,
#     1,
#     "Roll orientation"
#   ],
#   [
#     "RollRate",
#     "rad/s",
#     "float",
#     1,
#     1,
#     "Roll rate"
#   ],
#   [
#     "RPM",
#     "revs/min",
#     "float",
#     1,
#     1,
#     "Engine rpm"
#   ],
#   [
#     "SessionFlags",
#     "irsdk_Flags",
#     "bitfield",
#     0,
#     1,
#     "Session flags"
#   ],
#   [
#     "SessionLapsRemain",
#     NaN,
#     "int",
#     1,
#     1,
#     "Laps left till session ends"
#   ],
#   [
#     "SessionNum",
#     NaN,
#     "int",
#     1,
#     1,
#     "Session number"
#   ],
#   [
#     "SessionState",
#     "i rsdk_SessionState",
#     "int",
#     1,
#     1,
#     "Session state"
#   ],
#   [
#     "SessionTime",
#     "s",
#     "double",
#     1,
#     1,
#     "Seconds since session start"
#   ],
#   [
#     "SessionTimeRemain",
#     "s",
#     "double",
#     1,
#     1,
#     "Seconds left till session ends"
#   ],
#   [
#     "SessionUniqueID",
#     NaN,
#     "int",
#     1,
#     1,
#     "Session ID"
#   ],
#   [
#     "ShiftGrindRPM",
#     "RPM",
#     "float",
#     1,
#     1,
#     "RPM of shifter grinding noise"
#   ],
#   [
#     "ShiftIndicatorPct",
#     "%",
#     "float",
#     1,
#     1,
#     "DEPRECATED use DriverCarSLBlinkRPM instead"
#   ],
#   [
#     "ShiftPowerPct",
#     "%",
#     "float",
#     1,
#     1,
#     "Friction torque applied to gears when shifting or grinding"
#   ],
#   [
#     "Skies",
#     NaN,
#     "int",
#     1,
#     1,
#     "Skies (0=clear/1=p cloudy/2=m cloudy/3=overcast)"
#   ],
#   [
#     "Speed",
#     "m/s",
#     "float",
#     1,
#     1,
#     "GPS vehicle speed"
#   ],
#   [
#     "SteeringWheelAngle",
#     "rad",
#     "float",
#     1,
#     1,
#     "Steering wheel angle"
#   ],
#   [
#     "SteeringWheelAngleMax",
#     "rad",
#     "float",
#     1,
#     1,
#     "Steering wheel max angle"
#   ],
#   [
#     "SteeringWheelPctDamper",
#     "%",
#     "float",
#     1,
#     1,
#     "Force feedback % max damping"
#   ],
#   [
#     "SteeringWheelPctTorque",
#     "%",
#     "float",
#     1,
#     1,
#     "Force feedback % max torque on steering shaft unsigned"
#   ],
#   [
#     "SteeringWheelPctTorqueSign",
#     "%",
#     "float",
#     1,
#     1,
#     "Force feedback % max torque on steering shaft signed"
#   ],
#   [
#     "SteeringWheelPctTorqueSignStops",
#     "%",
#     "float",
#     1,
#     1,
#     "Force feedback % max torque on steering shaft signed stops"
#   ],
#   [
#     "SteeringWheelPeakForceNm",
#     "N*m",
#     "float",
#     0,
#     1,
#     "Peak torque mapping to direct input units for FFB"
#   ],
#   [
#     "SteeringWheelTorque",
#     "N*m",
#     "float",
#     1,
#     1,
#     "Output torque on steering shaft"
#   ],
#   [
#     "Throttle",
#     "%",
#     "float",
#     1,
#     1,
#     "0=off throttle to 1=full throttle"
#   ],
#   [
#     "ThrottleRaw",
#     "%",
#     "float",
#     1,
#     1,
#     "Raw throttle input 0=off throttle to 1=full throttle"
#   ],
#   [
#     "TrackTemp",
#     "C",
#     "float",
#     1,
#     1,
#     "Temperature of track at start/finish line"
#   ],
#   [
#     "TrackTempCrew",
#     "C",
#     "float",
#     1,
#     1,
#     "Temperature of track measured by crew around track"
#   ],
#   [
#     "VelocityX",
#     "m/s",
#     "float",
#     1,
#     1,
#     "X velocity"
#   ],
#   [
#     "VelocityY",
#     "m/s",
#     "float",
#     1,
#     1,
#     "Y velocity"
#   ],
#   [
#     "VelocityZ",
#     "m/s",
#     "float",
#     1,
#     1,
#     "Z velocity"
#   ],
#   [
#     "VertAccel",
#     "m/s^2",
#     "float",
#     1,
#     1,
#     "Vertical acceleration (including gravity)"
#   ],
#   [
#     "Voltage",
#     "V",
#     "float",
#     1,
#     1,
#     "Engine voltage"
#   ],
#   [
#     "WaterLevel",
#     "l",
#     "float",
#     1,
#     1,
#     "Engine coolant level"
#   ],
#   [
#     "WaterTemp",
#     "C",
#     "float",
#     1,
#     1,
#     "Engine coolant temp"
#   ],
#   [
#     "WeatherType",
#     NaN,
#     "int",
#     1,
#     1,
#     "Weather type (0=constant  1=dynamic)"
#   ],
#   [
#     "WindDir",
#     "rad",
#     "float",
#     1,
#     1,
#     "Wind direction at start/finish line"
#   ],
#   [
#     "WindVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "Wind velocity at start/finish line"
#   ],
#   [
#     "Yaw",
#     "rad",
#     "float",
#     1,
#     1,
#     "Yaw orientation"
#   ],
#   [
#     "YawNorth",
#     "rad",
#     "float",
#     1,
#     1,
#     "Yaw orientation relative to north"
#   ],
#   [
#     "YawRate",
#     "rad/s",
#     "float",
#     1,
#     1,
#     "Yaw rate"
#   ],
#   [
#     "CFrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "CF ride height"
#   ],
#   [
#     "CFshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "CF shock deflection"
#   ],
#   [
#     "CFshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "CF shock velocity"
#   ],
#   [
#     "CFSRrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "CFSR ride height"
#   ],
#   [
#     "CRrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "CR ride height"
#   ],
#   [
#     "CRshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "CR shock deflection"
#   ],
#   [
#     "CRshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "CR shock velocity"
#   ],
#   [
#     "dcABS",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car abs adjustment"
#   ],
#   [
#     "dcAntiRollFront",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car front anti roll bar adjustment"
#   ],
#   [
#     "dcAntiRollRear",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car rear anti roll bar adjustment"
#   ],
#   [
#     "dcBoostLevel",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car boost level adjustment"
#   ],
#   [
#     "dcBrakeBias",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car brake bias adjustment"
#   ],
#   [
#     "dcBrakeBias",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car brake bias adjustment"
#   ],
#   [
#     "dcDiffEntry",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car diff entry adjustment"
#   ],
#   [
#     "dcDiffExit",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car diff exit adjustment"
#   ],
#   [
#     "dcDiffMiddle",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car diff middle adjustment"
#   ],
#   [
#     "dcEngineBraking",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car engine braking adjustment"
#   ],
#   [
#     "dcEnginePower",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car engine power adjustment"
#   ],
#   [
#     "dcFuelMixture",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car fuel mixture adjustment"
#   ],
#   [
#     "dcRevLimiter",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car rev limiter adjustment"
#   ],
#   [
#     "dcThrottleShape",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car throttle shape adjustment"
#   ],
#   [
#     "dcTractionControl",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car traction control adjustment"
#   ],
#   [
#     "dcTractionControl2",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car traction control 2 adjustment"
#   ],
#   [
#     "dcTractionControlToggle",
#     NaN,
#     "bool",
#     1,
#     1,
#     "In car traction control active"
#   ],
#   [
#     "dcWeightJackerLeft",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car left weight jacker adjustment"
#   ],
#   [
#     "dcWeightJackerRight",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car right weight jacker adjustment"
#   ],
#   [
#     "dcWingFront",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car front wing adjustment"
#   ],
#   [
#     "dcWingRear",
#     NaN,
#     "float",
#     1,
#     1,
#     "In car rear wing adjustment"
#   ],
#   [
#     "dpFNOMKnobSetting",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop front flap adjustment"
#   ],
#   [
#     "dpFUFangleIndex",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop front upper flap adjustment"
#   ],
#   [
#     "dpFWingAngle",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop front wing adjustment"
#   ],
#   [
#     "dpFWingIndex",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop front wing adjustment"
#   ],
#   [
#     "dpLrWedgeAdj",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop lr spring offset adjustment"
#   ],
#   [
#     "dpPSSetting",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop power steering adjustment"
#   ],
#   [
#     "dpQtape",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop qtape adjustment"
#   ],
#   [
#     "dpRBarSetting",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rear bar adjustment"
#   ],
#   [
#     "dpRFTruckarmP1Dz",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rftruckarmP1Dz adjustment"
#   ],
#   [
#     "dpRRDamperPerchOffsetm",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop right rear dampter perch offset adjustment"
#   ],
#   [
#     "dpRrPerchOffsetm",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop right rear spring offset adjustment"
#   ],
#   [
#     "dpRrWedgeAdj",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rr spring offset adjustment"
#   ],
#   [
#     "dpRWingAngle",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rear wing adjustment"
#   ],
#   [
#     "dpRWingIndex",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rear wing adjustment"
#   ],
#   [
#     "dpRWingSetting",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop rear wing adjustment"
#   ],
#   [
#     "dpTruckarmP1Dz",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop truckarmP1Dz adjustment"
#   ],
#   [
#     "dpWedgeAdj",
#     NaN,
#     "float",
#     1,
#     1,
#     "Pitstop wedge adjustment"
#   ],
#   [
#     "LFbrakeLinePress",
#     "bar",
#     "float",
#     1,
#     1,
#     "LF  brake line pressure"
#   ],
#   [
#     "LFcoldPressure",
#     "kPa",
#     "float",
#     1,
#     1,
#     "LF tire cold pressure  as set in the garage"
#   ],
#   [
#     "LFpressure",
#     "kPa",
#     "float",
#     1,
#     0,
#     "LF tire pressure"
#   ],
#   [
#     "LFrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "LF ride height"
#   ],
#   [
#     "LFshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "LF shock deflection"
#   ],
#   [
#     "LFshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "LF shock velocity"
#   ],
#   [
#     "LFspeed",
#     "m/s",
#     "float",
#     1,
#     1,
#     "LF wheel speed"
#   ],
#   [
#     "LFtempCL",
#     "C",
#     "float",
#     1,
#     1,
#     "LF tire left carcass temperature"
#   ],
#   [
#     "LFtempCM",
#     "C",
#     "float",
#     1,
#     1,
#     "LF tire middle carcass temperature"
#   ],
#   [
#     "LFtempCR",
#     "C",
#     "float",
#     1,
#     1,
#     "LF tire right carcass temperature"
#   ],
#   [
#     "LFtempL",
#     "C",
#     "float",
#     1,
#     0,
#     "LF tire left surface temperature"
#   ],
#   [
#     "LFtempM",
#     "C",
#     "float",
#     1,
#     0,
#     "LF tire middle surface temperature"
#   ],
#   [
#     "LFtempR",
#     "C",
#     "float",
#     1,
#     0,
#     "LF tire right surface temperature"
#   ],
#   [
#     "LFwearL",
#     "%",
#     "float",
#     1,
#     1,
#     "LF tire left percent tread remaining"
#   ],
#   [
#     "LFwearM",
#     "%",
#     "float",
#     1,
#     1,
#     "LF tire middle percent tread remaining"
#   ],
#   [
#     "LFwearR",
#     "%",
#     "float",
#     1,
#     1,
#     "LF tire right percent tread remaining"
#   ],
#   [
#     "LRbrakeLinePress",
#     "bar",
#     "float",
#     1,
#     1,
#     "LR  brake line pressure"
#   ],
#   [
#     "LRcoldPressure",
#     "kPa",
#     "float",
#     1,
#     1,
#     "LR tire cold pressure  as set in the garage"
#   ],
#   [
#     "LRpressure",
#     "kPa",
#     "float",
#     1,
#     0,
#     "LR tire pressure"
#   ],
#   [
#     "LRrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "LR ride height"
#   ],
#   [
#     "LRshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "LR shock deflection"
#   ],
#   [
#     "LRshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "LR shock velocity"
#   ],
#   [
#     "LRspeed",
#     "m/s",
#     "float",
#     1,
#     1,
#     "LR wheel speed"
#   ],
#   [
#     "LRtempCL",
#     "C",
#     "float",
#     1,
#     1,
#     "LR tire left carcass temperature"
#   ],
#   [
#     "LRtempCM",
#     "C",
#     "float",
#     1,
#     1,
#     "LR tire middle carcass temperature"
#   ],
#   [
#     "LRtempCR",
#     "C",
#     "float",
#     1,
#     1,
#     "LR tire right carcass temperature"
#   ],
#   [
#     "LRtempL",
#     "C",
#     "float",
#     1,
#     0,
#     "LR tire left surface temperature"
#   ],
#   [
#     "LRtempM",
#     "C",
#     "float",
#     1,
#     0,
#     "LR tire middle surface temperature"
#   ],
#   [
#     "LRtempR",
#     "C",
#     "float",
#     1,
#     0,
#     "LR tire right surface temperature"
#   ],
#   [
#     "LRwearL",
#     "%",
#     "float",
#     1,
#     1,
#     "LR tire left percent tread remaining"
#   ],
#   [
#     "LRwearM",
#     "%",
#     "float",
#     1,
#     1,
#     "LR tire middle percent tread remaining"
#   ],
#   [
#     "LRwearR",
#     "%",
#     "float",
#     1,
#     1,
#     "LR tire right percent tread remaining"
#   ],
#   [
#     "RFbrakeLinePress",
#     "bar",
#     "float",
#     1,
#     1,
#     "RF  brake line pressure"
#   ],
#   [
#     "RFcoldPressure",
#     "kPa",
#     "float",
#     1,
#     1,
#     "RF tire cold pressure  as set in the garage"
#   ],
#   [
#     "RFpressure",
#     "kPa",
#     "float",
#     1,
#     0,
#     "RF tire pressure"
#   ],
#   [
#     "RFrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "RF ride height"
#   ],
#   [
#     "RFshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "RF shock deflection"
#   ],
#   [
#     "RFshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "RF shock velocity"
#   ],
#   [
#     "RFspeed",
#     "m/s",
#     "float",
#     1,
#     1,
#     "RF wheel speed"
#   ],
#   [
#     "RFtempCL",
#     "C",
#     "float",
#     1,
#     1,
#     "RF tire left carcass temperature"
#   ],
#   [
#     "RFtempCM",
#     "C",
#     "float",
#     1,
#     1,
#     "RF tire middle carcass temperature"
#   ],
#   [
#     "RFtempCR",
#     "C",
#     "float",
#     1,
#     1,
#     "RF tire right carcass temperature"
#   ],
#   [
#     "RFtempL",
#     "C",
#     "float",
#     1,
#     0,
#     "RF tire left surface temperature"
#   ],
#   [
#     "RFtempM",
#     "C",
#     "float",
#     1,
#     0,
#     "RF tire middle surface temperature"
#   ],
#   [
#     "RFtempR",
#     "C",
#     "float",
#     1,
#     0,
#     "RF tire right surface temperature"
#   ],
#   [
#     "RFwearL",
#     "%",
#     "float",
#     1,
#     1,
#     "RF tire left percent tread remaining"
#   ],
#   [
#     "RFwearM",
#     "%",
#     "float",
#     1,
#     1,
#     "RF tire middle percent tread remaining"
#   ],
#   [
#     "RFwearR",
#     "%",
#     "float",
#     1,
#     1,
#     "RF tire right percent tread remaining"
#   ],
#   [
#     "RRbrakeLinePress",
#     "bar",
#     "float",
#     1,
#     1,
#     "R  brake line pressure"
#   ],
#   [
#     "RRcoldPressure",
#     "kPa",
#     "float",
#     1,
#     1,
#     "RR tire cold pressure  as set in the garage"
#   ],
#   [
#     "RRpressure",
#     "kPa",
#     "float",
#     1,
#     0,
#     "RR tire pressure"
#   ],
#   [
#     "RRrideHeight",
#     "m",
#     "float",
#     1,
#     0,
#     "RR ride height"
#   ],
#   [
#     "RRshockDefl",
#     "m",
#     "float",
#     1,
#     1,
#     "RR shock deflection"
#   ],
#   [
#     "RRshockVel",
#     "m/s",
#     "float",
#     1,
#     1,
#     "RR shock velocity"
#   ],
#   [
#     "RRspeed",
#     "m/s",
#     "float",
#     1,
#     1,
#     "RR wheel speed"
#   ],
#   [
#     "RRtempCL",
#     "C",
#     "float",
#     1,
#     1,
#     "RR tire left carcass temperature"
#   ],
#   [
#     "RRtempCM",
#     "C",
#     "float",
#     1,
#     1,
#     "RR tire middle carcass temperature"
#   ],
#   [
#     "RRtempCR",
#     "C",
#     "float",
#     1,
#     1,
#     "RR tire right carcass temperature"
#   ],
#   [
#     "RRtempL",
#     "C",
#     "float",
#     1,
#     0,
#     "RR tire left surface temperature"
#   ],
#   [
#     "RRtempM",
#     "C",
#     "float",
#     1,
#     0,
#     "RR tire middle surface temperature"
#   ],
#   [
#     "RRtempR",
#     "C",
#     "float",
#     1,
#     0,
#     "RR tire right surface temperature"
#   ],
#   [
#     "RRwearL",
#     "%",
#     "float",
#     1,
#     1,
#     "RR tire left percent tread remaining"
#   ],
#   [
#     "RRwearM",
#     "%",
#     "float",
#     1,
#     1,
#     "RR tire middle percent tread remaining"
#   ],
#   [
#     "RRwearR",
#     "%",
#     "float",
#     1,
#     1,
#     "RR tire right percent tread remaining"
#   ],
#   [
#     "CarIdxClassPosition",
#     NaN,
#     "int",
#     0,
#     1,
#     "Cars class position in race by car index"
#   ],
#   [
#     "CarIdxEstTime",
#     "s",
#     "float",
#     0,
#     1,
#     "Estimated time to reach current location on track"
#   ],
#   [
#     "CarIdxF2Time",
#     "s",
#     "float",
#     0,
#     1,
#     "Race time behind leader or fastest lap time otherwise"
#   ],
#   [
#     "CarIdxGear",
#     NaN,
#     "int",
#     0,
#     1,
#     "-1=reverse  0=neutral  1..n=current gear by car index"
#   ],
#   [
#     "CarIdxLap",
#     NaN,
#     "int",
#     0,
#     1,
#     "Lap count by car index"
#   ],
#   [
#     "CarIdxLapDistPct",
#     "%",
#     "float",
#     0,
#     1,
#     "Percentage distance around lap by car index"
#   ],
#   [
#     "CarIdxOnPitRoad",
#     NaN,
#     "bool",
#     0,
#     1,
#     "On pit road between the cones by car index"
#   ],
#   [
#     "CarIdxPosition",
#     NaN,
#     "int",
#     0,
#     1,
#     "Cars position in race by car index"
#   ],
#   [
#     "CarIdxRPM",
#     "r evs/min",
#     "float",
#     0,
#     1,
#     "Engine rpm by car index"
#   ],
#   [
#     "CarIdxSteer",
#     "rad",
#     "float",
#     0,
#     1,
#     "Steering wheel angle by car index"
#   ],
#   [
#     "CarIdxTrackSurface",
#     "irsdk_TrkLoc",
#     "int",
#     0,
#     1,
#     "Track surface type by car index"
#   ]
# ]

# %%
print(json.dumps(all_vars, indent=2))
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[2], line 2
#       1 file1 = "Y:/code/sim-racing/irsdk++/docs/telemetry_11_23_15.pdf"
# ----> 2 table = tabula.read_pdf(file1,pages=1)
#       3 table[0]
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\tabula\io.py:395, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     392     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     394 try:
# --> 395     output = _run(
#     396         tabula_options,
#     397         java_options,
#     398         path,
#     399         encoding=encoding,
#     400         force_subprocess=force_subprocess,
#     401     )
#     402 finally:
#     403     if temporary:
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\tabula\io.py:74, in _run(options, java_options, path, encoding, force_subprocess)
#      69     _tabula_vm = SubprocessTabula(
#      70         java_options=java_options, silent=options.silent, encoding=encoding
#      71     )
#      73 if not _tabula_vm:
# ---> 74     _tabula_vm = TabulaVm(java_options=java_options, silent=options.silent)
#      75     if _tabula_vm and not _tabula_vm.tabula:
#      76         _tabula_vm = SubprocessTabula(
#      77             java_options=java_options, silent=options.silent, encoding=encoding
#      78         )
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\tabula\backend.py:45, in TabulaVm.__init__(self, java_options, silent)
#      36     if silent:
#      37         java_options.extend(
#      38             (
#      39                 "-Dorg.slf4j.simpleLogger.defaultLogLevel=off",
#    (...)
#      42             )
#      43         )
# ---> 45     jpype.startJVM(*java_options, convertStrings=False)
#      47 import java.lang as lang
#      48 import technology.tabula as tabula
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\jpype\_core.py:219, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     216         jvmargs = jvmargs[1:]
#     218 if not jvmpath:
# --> 219     jvmpath = getDefaultJVMPath()
#     220 else:
#     221     # Allow the path to be a PathLike.
#     222     jvmpath = os.fspath(jvmpath)
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\jpype\_jvmfinder.py:74, in getDefaultJVMPath()
#      72 else:
#      73     finder = LinuxJVMFinder()
# ---> 74 return finder.get_jvm_path()
#
# File Y:\code\sim-racing\iracing-python\.venv\ir-data-playground-python\Lib\site-packages\jpype\_jvmfinder.py:212, in JVMFinder.get_jvm_path(self)
#     210 if jvm_notsupport_ext is not None:
#     211     raise jvm_notsupport_ext
# --> 212 raise JVMNotFoundException("No JVM shared library file ({0}) "
#     213                            "found. Try setting up the JAVA_HOME "
#     214                            "environment variable properly."
#     215                            .format(self._libfile))
#
# JVMNotFoundException: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.

# %%
def enum_var_names():
    return '\n'.join([record[0] + "," for record in all_vars])

code = (f"""
enum IRAllVarName {{
  {enum_var_names()}   
}};        
""")

code
# Out:
# '\nenum IRAllVarName {\n  AirDensity,\nAirPressure,\nAirTemp,\nAlt,\nBrake,\nBrakeRaw,\nCamCameraNumber,\nCamCameraState,\nCamCarIdx,\nCamGroupNumber,\nClutch,\nCpuUsageBG,\nDCDriversSoFar,\nDCLapStatus,\nDisplayUnits,\nDriverMarker,\nEngineWarnings,\nEnterExitReset,\nFogLevel,\nFrameRate,\nFuelLevel,\nFuelLevelPct,\nFuelPress,\nFuelUsePerHour,\nGear,\nIsDiskLoggingActive,\nIsDiskLoggingEnabled,\nIsInGarage,\nIsOnTrack,\nIsOnTrackCar,\nIsReplayPlaying,\nLap,\nLapBestLap,\nLapBestLapTime,\nLapBestNLapLap,\nLapBestNLapTime,\nLapCurrentLapTime,\nLapDeltaToBestLap,\nLapDeltaToBestLap_DD,\nLapDeltaToBestLap_OK,\nLapDeltaToOptimalLap,\nLapDeltaToOptimalLap_DD,\nLapDeltaToOptimalLap_OK,\nLapDeltaToSessionBestLap,\nLapDeltaToSessionBestLap_DD,\nLapDeltaToSessionBestLap_OK,\nLapDeltaToSessionLastlLap,\nLapDeltaToSessionLastlLap_DD,\nLapDeltaToSessionLastlLap_OK,\nLapDeltaToSessionOptimalLap,\nLapDeltaToSessionOptimalLap_DD,\nLapDeltaToSessionOptimalLap_OK,\nLapDist,\nLapDistPct,\nLapLasNLapSeq,\nLapLastLapTime,\nLapLastNLapTime,\nLat,\nLatAccel,\nLon,\nLongAccel,\nManifoldPress,\nOilLevel,\nOilPress,\nOilTemp,\nOnPitRoad,\nPitch,\nPitchRate,\nPitOptRepairLeft,\nPitRepairLeft,\nPitSvFlags,\nPitSvFuel,\nPitSvLFP,\nPitSvLRP,\nPitSvRFP,\nPitSvRRP,\nPlayerCarClassPosition,\nPlayerCarPosition,\nRaceLaps,\nRadioTransmitCarIdx,\nRadioTransmitFrequencyIdx,\nRadioTransmitRadioIdx,\nRelativeHumidity,\nReplayFrameNum,\nReplayFrameNumEnd,\nReplayPlaySlowMotion,\nReplayPlaySpeed,\nReplaySessionNum,\nReplaySessionTime,\nRoll,\nRollRate,\nRPM,\nSessionFlags,\nSessionLapsRemain,\nSessionNum,\nSessionState,\nSessionTime,\nSessionTimeRemain,\nSessionUniqueID,\nShiftGrindRPM,\nShiftIndicatorPct,\nShiftPowerPct,\nSkies,\nSpeed,\nSteeringWheelAngle,\nSteeringWheelAngleMax,\nSteeringWheelPctDamper,\nSteeringWheelPctTorque,\nSteeringWheelPctTorqueSign,\nSteeringWheelPctTorqueSignStops,\nSteeringWheelPeakForceNm,\nSteeringWheelTorque,\nThrottle,\nThrottleRaw,\nTrackTemp,\nTrackTempCrew,\nVelocityX,\nVelocityY,\nVelocityZ,\nVertAccel,\nVoltage,\nWaterLevel,\nWaterTemp,\nWeatherType,\nWindDir,\nWindVel,\nYaw,\nYawNorth,\nYawRate,\nCFrideHeight,\nCFshockDefl,\nCFshockVel,\nCFSRrideHeight,\nCRrideHeight,\nCRshockDefl,\nCRshockVel,\ndcABS,\ndcAntiRollFront,\ndcAntiRollRear,\ndcBoostLevel,\ndcBrakeBias,\ndcBrakeBias,\ndcDiffEntry,\ndcDiffExit,\ndcDiffMiddle,\ndcEngineBraking,\ndcEnginePower,\ndcFuelMixture,\ndcRevLimiter,\ndcThrottleShape,\ndcTractionControl,\ndcTractionControl2,\ndcTractionControlToggle,\ndcWeightJackerLeft,\ndcWeightJackerRight,\ndcWingFront,\ndcWingRear,\ndpFNOMKnobSetting,\ndpFUFangleIndex,\ndpFWingAngle,\ndpFWingIndex,\ndpLrWedgeAdj,\ndpPSSetting,\ndpQtape,\ndpRBarSetting,\ndpRFTruckarmP1Dz,\ndpRRDamperPerchOffsetm,\ndpRrPerchOffsetm,\ndpRrWedgeAdj,\ndpRWingAngle,\ndpRWingIndex,\ndpRWingSetting,\ndpTruckarmP1Dz,\ndpWedgeAdj,\nLFbrakeLinePress,\nLFcoldPressure,\nLFpressure,\nLFrideHeight,\nLFshockDefl,\nLFshockVel,\nLFspeed,\nLFtempCL,\nLFtempCM,\nLFtempCR,\nLFtempL,\nLFtempM,\nLFtempR,\nLFwearL,\nLFwearM,\nLFwearR,\nLRbrakeLinePress,\nLRcoldPressure,\nLRpressure,\nLRrideHeight,\nLRshockDefl,\nLRshockVel,\nLRspeed,\nLRtempCL,\nLRtempCM,\nLRtempCR,\nLRtempL,\nLRtempM,\nLRtempR,\nLRwearL,\nLRwearM,\nLRwearR,\nRFbrakeLinePress,\nRFcoldPressure,\nRFpressure,\nRFrideHeight,\nRFshockDefl,\nRFshockVel,\nRFspeed,\nRFtempCL,\nRFtempCM,\nRFtempCR,\nRFtempL,\nRFtempM,\nRFtempR,\nRFwearL,\nRFwearM,\nRFwearR,\nRRbrakeLinePress,\nRRcoldPressure,\nRRpressure,\nRRrideHeight,\nRRshockDefl,\nRRshockVel,\nRRspeed,\nRRtempCL,\nRRtempCM,\nRRtempCR,\nRRtempL,\nRRtempM,\nRRtempR,\nRRwearL,\nRRwearM,\nRRwearR,\nCarIdxClassPosition,\nCarIdxEstTime,\nCarIdxF2Time,\nCarIdxGear,\nCarIdxLap,\nCarIdxLapDistPct,\nCarIdxOnPitRoad,\nCarIdxPosition,\nCarIdxRPM,\nCarIdxSteer,\nCarIdxTrackSurface,   \n};        \n'
